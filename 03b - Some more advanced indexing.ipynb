# %% [markdown]
# # Advanced indexing

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
try:
    import seaborn
except ImportError:
    pass

# %% [markdown]
# This dataset is borrowed from the [PyCon tutorial of Brandon Rhodes](https://github.com/brandon-rhodes/pycon-pandas-tutorial/) (so all credit to him!). You can download these data from here: [`titles.csv`](https://drive.google.com/file/d/0B3G70MlBnCgKa0U4WFdWdGdVOFU/view?usp=sharing) and [`cast.csv`](https://drive.google.com/file/d/0B3G70MlBnCgKRzRmTWdQTUdjNnM/view?usp=sharing) and put them in the `/data` folder.

# %%
cast = pd.read_csv('data/cast.csv')
cast.head()
# Out:
#                                title  year       name   type character   n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself NaN

# %%
titles = pd.read_csv('data/titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1        Ashes of Kukulcan  2016
# 2  The Thousand Plane Raid  1969
# 3         Crucea de piatra  1993
# 4                   The 86  2015

# %% [markdown]
# ## Setting columns as the index

# %% [markdown]
# Why is it useful to have an index?
#
# - Giving meaningful labels to your data -> easier to remember which data are where
# - Unleash some powerful methods, eg with a DatetimeIndex for time series
# - Easier and faster selection of data
#
# It is this last one we are going to explore here!

# %% [markdown]
# Setting the `title` column as the index:

# %%
pd.options.display.max_rows = 10

# %%
cast
# Out:
#                                      title  year                         name  \
# 0                          Suuri illusioni  1985                       Homo $
# 1           Gangsta Rap: The Glockumentary  2007                    Too $hort
# 2                        Menace II Society  1993                    Too $hort
# 3        Porndogs: The Adventures of Sadie  2009                    Too $hort
# 4                       Stop Pepper Palmer  2014                    Too $hort
# ...                                    ...   ...                          ...
# 3333690                     Stuttur Frakki  1993    Sveinbj?rg ??rhallsd?ttir
# 3333691                            Foxtrot  1988            Lilja ??risd?ttir
# 3333692   Niceland (Population. 1.000.002)  2004    Sigr??ur J?na ??risd?ttir
# 3333693                       U.S.S.S.S...  2003  Krist?n Andrea ??r?ard?ttir
# 3333694                  Bye Bye Blue Bird  1999                 Rosa ? R?gvu
#
#             type               character   n
# 0          actor                  Guests  22
# 1          actor                 Himself NaN
# 2          actor                 Lew-Loc  27
# 3          actor                   Bosco   3
# 4          actor                 Himself NaN
# ...          ...                     ...  ..
# 3333690  actress              Flugfreyja  24
# 3333691  actress                    D?ra  24
# 3333692  actress            Woman in Bus  26
# 3333693  actress  Afgr.dama ? bens?nst??  17
# 3333694  actress       Pensionatv?rtinde NaN
#
# [3333695 rows x 6 columns]

# %%
c = cast.set_index('title')

# %%
c.head()
# Out:
#                                    year       name   type character   n
# title
# Suuri illusioni                    1985     Homo $  actor    Guests  22
# Gangsta Rap: The Glockumentary     2007  Too $hort  actor   Himself NaN
# Menace II Society                  1993  Too $hort  actor   Lew-Loc  27
# Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3
# Stop Pepper Palmer                 2014  Too $hort  actor   Himself NaN

# %% [markdown]
# Instead of doing:

# %%
# %%time
cast[cast['title'] == 'Hamlet']
# Out:
# CPU times: user 480 ms, sys: 8 ms, total: 488 ms
# Wall time: 489 ms
#           title  year              name     type              character   n
# 1456     Hamlet  1996        Riz Abbasi    actor  Attendant to Claudius   1
# 6710     Hamlet  1921  Fritz Achterberg    actor            Fortinbras,   9
# 10274    Hamlet  2009      Hayden Adams    actor                Laertes   7
# 10275    Hamlet  2009      Hayden Adams    actor                 Player   7
# 12743    Hamlet  1913       Eric Adeney    actor               Reynaldo  14
# ...         ...   ...               ...      ...                    ...  ..
# 3212647  Hamlet  1964      Carol Teitel  actress                   Lady NaN
# 3236803  Hamlet  1969    Jennifer Tudor  actress             Court lady  23
# 3257437  Hamlet  2000      Diane Venora  actress               Gertrude   3
# 3284728  Hamlet  1996     Perdita Weeks  actress          Second Player  44
# 3304265  Hamlet  1996      Kate Winslet  actress                Ophelia  46
#
# [299 rows x 6 columns]

# %% [markdown]
# we can now do:

# %%
# %%time
c.loc['Stop Pepper Palmer']
# Out:
# CPU times: user 176 ms, sys: 8 ms, total: 184 ms
# Wall time: 183 ms
#                     year                   name     type  \
# title
# Stop Pepper Palmer  2014              Too $hort    actor
# Stop Pepper Palmer  2014         Spencer Belnap    actor
# Stop Pepper Palmer  2014        Carlton Bluford    actor
# Stop Pepper Palmer  2014         Nasheda Caudle    actor
# Stop Pepper Palmer  2014            Andrew Diaz    actor
# ...                  ...                    ...      ...
# Stop Pepper Palmer  2014  Rachel Patten-Moskios  actress
# Stop Pepper Palmer  2014           Amy Savannah  actress
# Stop Pepper Palmer  2014              Eve Speer  actress
# Stop Pepper Palmer  2014   Catherine Standiford  actress
# Stop Pepper Palmer  2014       Rebecca Turkanis  actress
#
#                                  character   n
# title
# Stop Pepper Palmer                 Himself NaN
# Stop Pepper Palmer                  Lawyer NaN
# Stop Pepper Palmer          Jerome Johnson NaN
# Stop Pepper Palmer          Back up Dancer NaN
# Stop Pepper Palmer           Pepper Palmer NaN
# ...                                    ...  ..
# Stop Pepper Palmer             Club Patron NaN
# Stop Pepper Palmer  Too Short's Girlfriend NaN
# Stop Pepper Palmer                 Trustee NaN
# Stop Pepper Palmer             Club Patron NaN
# Stop Pepper Palmer                 Barista NaN
#
# [34 rows x 5 columns]

# %% [markdown]
# But you can also have multiple columns as the index, leading to a **multi-index or hierarchical index**:

# %%
c = cast.set_index(['title', 'year'])

# %%
c.head()
# Out:
#                                              name   type character   n
# title                             year
# Suuri illusioni                   1985     Homo $  actor    Guests  22
# Gangsta Rap: The Glockumentary    2007  Too $hort  actor   Himself NaN
# Menace II Society                 1993  Too $hort  actor   Lew-Loc  27
# Porndogs: The Adventures of Sadie 2009  Too $hort  actor     Bosco   3
# Stop Pepper Palmer                2014  Too $hort  actor   Himself NaN

# %%
# %%time
c.loc[('Hamlet', 2000),:]
# Out:
# CPU times: user 32 ms, sys: 12 ms, total: 44 ms
# Wall time: 44.8 ms
# /home/joris/miniconda/envs/python3/lib/python3.4/site-packages/pandas/core/index.py:5091: PerformanceWarning: indexing past lexsort depth may impact performance.
#   PerformanceWarning)
#                          name     type                 character   n
# title  year
# Hamlet 2000     Casey Affleck    actor                Fortinbras  15
#        2000       Paul Bartel    actor                     Osric  14
#        2000     Paul Ferriter    actor  Special Guest Appearance  23
#        2000   Larry Fessenden    actor               Kissing Man  24
#        2000        Karl Geary    actor                   Horatio   8
# ...                       ...      ...                       ...  ..
#        2000   Anne (II) Nixon  actress  Special Guest Appearance  34
#        2000  India Reed Kotis  actress  Special Guest Appearance  29
#        2000   Kelly Sebastian  actress                 Secretary  39
#        2000      Julia Stiles  actress                   Ophelia   7
#        2000      Diane Venora  actress                  Gertrude   3
#
# [38 rows x 4 columns]

# %%
c2 = c.sort_index()

# %%
# %%time
c2.loc[('Hamlet', 2000),:]
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 9.64 ms
#                          name     type                 character   n
# title  year
# Hamlet 2000     Casey Affleck    actor                Fortinbras  15
#        2000       Paul Bartel    actor                     Osric  14
#        2000     Paul Ferriter    actor  Special Guest Appearance  23
#        2000   Larry Fessenden    actor               Kissing Man  24
#        2000        Karl Geary    actor                   Horatio   8
# ...                       ...      ...                       ...  ..
#        2000   Anne (II) Nixon  actress  Special Guest Appearance  34
#        2000  India Reed Kotis  actress  Special Guest Appearance  29
#        2000   Kelly Sebastian  actress                 Secretary  39
#        2000      Julia Stiles  actress                   Ophelia   7
#        2000      Diane Venora  actress                  Gertrude   3
#
# [38 rows x 4 columns]

# %%
c2.reset_index(['title', 'year'])
# Out:
#                            title  year                name     type  \
# 0               #1 Serial Killer  2013       Michael Alton    actor
# 1               #1 Serial Killer  2013          Aaron Aoki    actor
# 2               #1 Serial Killer  2013   Zachary (X) Brown    actor
# 3               #1 Serial Killer  2013      Yvis Cannavale    actor
# 4               #1 Serial Killer  2013       Patrick Chien    actor
# ...                          ...   ...                 ...      ...
# 3333690  xXx: State of the Union  2005    Deborah S. Smith  actress
# 3333691  xXx: State of the Union  2005       Gina St. John  actress
# 3333692  xXx: State of the Union  2005  Paola (III) Torres  actress
# 3333693  xXx: State of the Union  2005      Samantha Tyler  actress
# 3333694  xXx: State of the Union  2005  Gay-Yee Westerhoff  actress
#
#                       character   n
# 0             Detective Roberts  17
# 1            Plastic Bag Victim  21
# 2        Africian American Teen  18
# 3                  Homeless Man  25
# 4                Cleaver Victim  22
# ...                         ...  ..
# 3333690          Business Woman NaN
# 3333691          Field Reporter  28
# 3333692            DC Executive NaN
# 3333693           Corvette Girl  38
# 3333694          String Quartet NaN
#
# [3333695 rows x 6 columns]
